# %%
# !pip install webdriver-manager selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import csv
# Out:
# Requirement already satisfied: webdriver-manager in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (3.8.4)
# Requirement already satisfied: selenium in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (3.141.0)
# Requirement already satisfied: requests in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from webdriver-manager) (2.26.0)
# Requirement already satisfied: tqdm in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from webdriver-manager) (4.62.3)
# Requirement already satisfied: python-dotenv in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from webdriver-manager) (0.19.2)
# Requirement already satisfied: urllib3 in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from selenium) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (3.3)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
print("Installing and running chrome webdriver")
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# Installing and running chrome webdriver

# %%
indeedCompanyBaseURL = 'https://www.indeed.com/'

# Change these constants
# Note - do not set the number of reviews to scrape per company over 100, otherwise indeed.com will block the scraper
# Trust me, I found out the hard way
NUMBER_OF_COMPANIES_TO_SCRAPE = 100
NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY = 60

# %%
companyURLs = {}
print("Beginning to scrape")
companyScraperBaseURL = 'https://www.indeed.com/jobs?q=software+intern&start='
for i in range(0,NUMBER_OF_COMPANIES_TO_SCRAPE,10):
    print("Scraping companies - ",i+10,"/",NUMBER_OF_COMPANIES_TO_SCRAPE)
    url = companyScraperBaseURL+str(i)
    driver.get(url)
    companies = driver.find_elements(By.CLASS_NAME,'companyOverviewLink')
    for company in companies:
        if company.text not in companyURLs:
            companyURLs[company.text] = (company.get_property('href'))

print("Company Scraping done")
# Out:
# Beginning to scrape
# Scraping companies -  10 / 100
# Scraping companies -  20 / 100
# Scraping companies -  30 / 100
# Scraping companies -  40 / 100
# Scraping companies -  50 / 100
# Scraping companies -  60 / 100
# Scraping companies -  70 / 100
# Scraping companies -  80 / 100
# Scraping companies -  90 / 100
# Scraping companies -  100 / 100
# Company Scraping done

# %%
reviews = {}

for i,company in enumerate(companyURLs):
    url = companyURLs[company]
    print()
    print("({0}/{1}) Scraping company reviews - {2}".format(i+1, len(companyURLs), company))
    for i in range(0,NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY,20):
        print("Progress - ",i+20,"/",NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY)
        newUrl = url+'/reviews?&start='+str(i)
        driver.get(newUrl)
        elems = driver.find_elements(By.CLASS_NAME,'eu4oa1w0')
        for elem in elems:
            if elem.tag_name=="span":
                txt = elem.text
                if txt!='':
                    if company not in reviews:
                        reviews[company] = ''
                    reviews[company]+=txt
# Out:
# (1/82) Scraping company reviews - Advanced Micro Devices, Inc.
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (2/82) Scraping company reviews - Stellantis
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (3/82) Scraping company reviews - BI WORLDWIDE
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (4/82) Scraping company reviews - Microsoft
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (5/82) Scraping company reviews - Peraton
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (6/82) Scraping company reviews - Lennox International
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (7/82) Scraping company reviews - Tandem Diabetes Care, Inc.
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (8/82) Scraping company reviews - Cybernet Systems Corporation
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (9/82) Scraping company reviews - Bayer
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (10/82) Scraping company reviews - Sandhills Global, Inc.
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (11/82) Scraping company reviews - Netflix
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (12/82) Scraping company reviews - Nelnet
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (13/82) Scraping company reviews - Pinterest
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (14/82) Scraping company reviews - C2FO
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
# (15/82) Scraping company reviews - Adobe
# Progress -  20 / 60
# Progress -  40 / 60
# Progress -  60 / 60
#
#