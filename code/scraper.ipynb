# %%
# !pip install webdriver-manager selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import csv
# Out:
# Requirement already satisfied: webdriver-manager in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (3.8.4)
# Requirement already satisfied: selenium in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (3.141.0)
# Requirement already satisfied: requests in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from webdriver-manager) (2.26.0)
# Requirement already satisfied: tqdm in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from webdriver-manager) (4.62.3)
# Requirement already satisfied: python-dotenv in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from webdriver-manager) (0.19.2)
# Requirement already satisfied: urllib3 in /Users/atharvchandratre/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from selenium) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/atharvchandratre/.local/lib/python3.9/site-packages (from requests->webdriver-manager) (3.3)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
print("Installing and running chrome webdriver")
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# Installing and running chrome webdriver

# %%
indeedCompanyBaseURL = 'https://www.indeed.com/'

# Change these constants
# Note - do not set the number of reviews to scrape per company over 150, otherwise indeed.com will block the scraper
# Trust me, I found out the hard way
NUMBER_OF_COMPANIES_TO_SCRAPE = 150
NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY = 100

# %%
companyURLs = {}
print("Beginning to scrape")
companyScraperBaseURL = 'https://www.indeed.com/jobs?q=software+intern&start='
for i in range(0,NUMBER_OF_COMPANIES_TO_SCRAPE,10):
    print("Scraping companies - ",i+10,"/",NUMBER_OF_COMPANIES_TO_SCRAPE)
    url = companyScraperBaseURL+str(i)
    driver.get(url)
    time.sleep(1)
    companies = driver.find_elements(By.CLASS_NAME,'companyOverviewLink')
    for company in companies:
        if company.text not in companyURLs:
            companyURLs[company.text] = (company.get_property('href'))

print("Company Scraping done")
# Out:
# Beginning to scrape
# Scraping companies -  10 / 200
# Scraping companies -  20 / 200
# Scraping companies -  30 / 200
# Scraping companies -  40 / 200
# Scraping companies -  50 / 200
# Scraping companies -  60 / 200
# Scraping companies -  70 / 200
# Scraping companies -  80 / 200
# Scraping companies -  90 / 200
# Scraping companies -  100 / 200
# Scraping companies -  110 / 200
# Scraping companies -  120 / 200
# Scraping companies -  130 / 200
# Scraping companies -  140 / 200
# Scraping companies -  150 / 200
# Scraping companies -  160 / 200
# Scraping companies -  170 / 200
# Scraping companies -  180 / 200
# Scraping companies -  190 / 200
# Scraping companies -  200 / 200
# Company Scraping done

# %%
reviews = {}

for i,company in enumerate(companyURLs):
    url = companyURLs[company]
    print()
    print("({0}/{1}) Scraping company reviews - {2}".format(i+1, len(companyURLs), company))
    for i in range(0,NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY,20):
        print("Progress - ",i+20,"/",NUMBER_OF_REVIEWS_TO_SCRAPE_PER_COMPANY)
        newUrl = url+'/reviews?&start='+str(i)
        driver.get(newUrl)
        elems = driver.find_elements(By.CLASS_NAME,'eu4oa1w0')
        for elem in elems:
            if elem.tag_name=="span":
                txt = elem.text
                if txt!='':
                    if company not in reviews:
                        reviews[company] = ''
                    reviews[company]+=' '+txt
# Out:
# (1/170) Scraping company reviews - pc/nametag
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (2/170) Scraping company reviews - Northrop Grumman
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (3/170) Scraping company reviews - Microsoft
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (4/170) Scraping company reviews - Advanced Micro Devices, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (5/170) Scraping company reviews - Adobe
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (6/170) Scraping company reviews - Netflix
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (7/170) Scraping company reviews - Bayer
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (8/170) Scraping company reviews - INTEL
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (9/170) Scraping company reviews - Amazon Dev Center U.S., Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (10/170) Scraping company reviews - BAE Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (11/170) Scraping company reviews - The Waldinger Corporation
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (12/170) Scraping company reviews - Sandhills Global, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (13/170) Scraping company reviews - Tandem Diabetes Care, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (14/170) Scraping company reviews - Pinterest
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (15/170) Scraping company reviews - BI WORLDWIDE
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (16/170) Scraping company reviews - Nelnet
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (17/170) Scraping company reviews - Zotec Partners
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (18/170) Scraping company reviews - WarnerMedia
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (19/170) Scraping company reviews - CACI
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (20/170) Scraping company reviews - Salesforce
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (21/170) Scraping company reviews - Lennox International
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (22/170) Scraping company reviews - Etsy
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (23/170) Scraping company reviews - Acuitus
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (24/170) Scraping company reviews - Geneva Trading
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (25/170) Scraping company reviews - Cybernet Systems Corporation
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (26/170) Scraping company reviews - Shure
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (27/170) Scraping company reviews - ByteDance
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (28/170) Scraping company reviews - Hewlett Packard Enterprise
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (29/170) Scraping company reviews - Duck Creek Technologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (30/170) Scraping company reviews - Home Depot / THD
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (31/170) Scraping company reviews - Braze
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (32/170) Scraping company reviews - ROUTEONE
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (33/170) Scraping company reviews - PerBlue
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (34/170) Scraping company reviews - Evive
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (35/170) Scraping company reviews - C2FO
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (36/170) Scraping company reviews - Epic
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (37/170) Scraping company reviews - Pekin Insurance
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (38/170) Scraping company reviews - ETC
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (39/170) Scraping company reviews - Baker Tilly US, LLP
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (40/170) Scraping company reviews - Cummins Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (41/170) Scraping company reviews - Leidos
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (42/170) Scraping company reviews - Orolia
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (43/170) Scraping company reviews - LOCKHEED MARTIN CORPORATION
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (44/170) Scraping company reviews - Patreon
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (45/170) Scraping company reviews - BOEING
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (46/170) Scraping company reviews - Direct Supply
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (47/170) Scraping company reviews - Oracle
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (48/170) Scraping company reviews - Global Traffic Technologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (49/170) Scraping company reviews - Mayo Clinic
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (50/170) Scraping company reviews - Booz Allen Hamilton
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (51/170) Scraping company reviews - Personify
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (52/170) Scraping company reviews - Skyward
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (53/170) Scraping company reviews - Amazon.com Services LLC
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (54/170) Scraping company reviews - Grant Street Group
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (55/170) Scraping company reviews - Alten Technology USA
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (56/170) Scraping company reviews - RGA
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (57/170) Scraping company reviews - Dimensional Innovations Inc
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (58/170) Scraping company reviews - ActiveCampaign
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (59/170) Scraping company reviews - Cadence Design Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (60/170) Scraping company reviews - J. F. Ahern Co.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (61/170) Scraping company reviews - One Medical
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (62/170) Scraping company reviews - Kasisto
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (63/170) Scraping company reviews - NOKIA
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (64/170) Scraping company reviews - Blizzard Entertainment
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (65/170) Scraping company reviews - Nordson
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (66/170) Scraping company reviews - IBM
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (67/170) Scraping company reviews - Plaid
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (68/170) Scraping company reviews - Blue Line Distribution
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (69/170) Scraping company reviews - HP
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (70/170) Scraping company reviews - New Leader Manufacturing
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (71/170) Scraping company reviews - The Coca-Cola Company
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (72/170) Scraping company reviews - Spectrum
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (73/170) Scraping company reviews - XIFIN
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (74/170) Scraping company reviews - Relativity
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (75/170) Scraping company reviews - Harman International
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (76/170) Scraping company reviews - Ohio County Healthcare
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (77/170) Scraping company reviews - DiDi Labs
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (78/170) Scraping company reviews - Texas Instruments
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (79/170) Scraping company reviews - TikTok
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (80/170) Scraping company reviews - Domo
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (81/170) Scraping company reviews - Nissan
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (82/170) Scraping company reviews - Electronic Arts
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (83/170) Scraping company reviews - Slack
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (84/170) Scraping company reviews - State Street
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (85/170) Scraping company reviews - BRADY WORLDWIDE INC
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (86/170) Scraping company reviews - Bunge
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (87/170) Scraping company reviews - Invoice Cloud
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (88/170) Scraping company reviews - Shamrock Trading Corporation
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (89/170) Scraping company reviews - ACIST Medical Systems, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (90/170) Scraping company reviews - Tesla
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (91/170) Scraping company reviews - Helmer Scientific
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (92/170) Scraping company reviews - Terra Engineering Ltd
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (93/170) Scraping company reviews - College Fresh Inc
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (94/170) Scraping company reviews - Taylor Corporation
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (95/170) Scraping company reviews - LCS - London Computer Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (96/170) Scraping company reviews - SubCom
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (97/170) Scraping company reviews - Uber
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (98/170) Scraping company reviews - NICE CXone
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (99/170) Scraping company reviews - Ricoh
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (100/170) Scraping company reviews - Oscar Health
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (101/170) Scraping company reviews - Exact Sciences Corporation
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (102/170) Scraping company reviews - Samsung Research America Internship
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (103/170) Scraping company reviews - Cisco Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (104/170) Scraping company reviews - Autodesk
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (105/170) Scraping company reviews - Commerce Bank
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (106/170) Scraping company reviews - Delta
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (107/170) Scraping company reviews - Netsmart Technologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (108/170) Scraping company reviews - Apple
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (109/170) Scraping company reviews - TriNet
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (110/170) Scraping company reviews - TSI Incorporated
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (111/170) Scraping company reviews - Zoom Video Communications, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (112/170) Scraping company reviews - Tyler Technologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (113/170) Scraping company reviews - Ripple
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (114/170) Scraping company reviews - Sirius XM
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (115/170) Scraping company reviews - Apptio
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (116/170) Scraping company reviews - Radiance Technologies Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (117/170) Scraping company reviews - S&P Global
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (118/170) Scraping company reviews - Assurity life Insurance Co
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (119/170) Scraping company reviews - Innovative Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (120/170) Scraping company reviews - redhat
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (121/170) Scraping company reviews - Applied Minds, LLC
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (122/170) Scraping company reviews - Roku
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (123/170) Scraping company reviews - Lacework
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (124/170) Scraping company reviews - Novanta
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (125/170) Scraping company reviews - Nasdaq, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (126/170) Scraping company reviews - Bandwidth
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (127/170) Scraping company reviews - Strata Decision Technology
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (128/170) Scraping company reviews - Prometric
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (129/170) Scraping company reviews - Atlassian
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (130/170) Scraping company reviews - Aptiv
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (131/170) Scraping company reviews - Credit Karma
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (132/170) Scraping company reviews - Altair Engineering
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (133/170) Scraping company reviews - Adaptive Biotechnologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (134/170) Scraping company reviews - Frontier Technology Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (135/170) Scraping company reviews - Mastercard
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (136/170) Scraping company reviews - Infineon Technologies
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (137/170) Scraping company reviews - Pavlov Media Inc
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (138/170) Scraping company reviews - FactSet Research Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (139/170) Scraping company reviews - Johns Hopkins Applied Physics Laboratory (APL)
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (140/170) Scraping company reviews - Belvedere Trading
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (141/170) Scraping company reviews - Recursion
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (142/170) Scraping company reviews - MAHLE
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (143/170) Scraping company reviews - KBKG
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (144/170) Scraping company reviews - ITW Food Equipment Group
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (145/170) Scraping company reviews - Amcor
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (146/170) Scraping company reviews - CNH Industrial
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (147/170) Scraping company reviews - Optiver
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (148/170) Scraping company reviews - Formlabs
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (149/170) Scraping company reviews - Con-Tech Manufacturing, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (150/170) Scraping company reviews - Internship Positions at Global Atlantic Financial...
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (151/170) Scraping company reviews - NimbleRx
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (152/170) Scraping company reviews - Arcesium
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (153/170) Scraping company reviews - ESRI, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (154/170) Scraping company reviews - RF-SMART
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (155/170) Scraping company reviews - BASYS Processing
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (156/170) Scraping company reviews - Apple Bank for Savings
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (157/170) Scraping company reviews - ABB
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (158/170) Scraping company reviews - Paramount
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (159/170) Scraping company reviews - AGCO
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (160/170) Scraping company reviews - SRC, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (161/170) Scraping company reviews - Lake Shore Cryotronics, Inc
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (162/170) Scraping company reviews - GuideOne Insurance
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (163/170) Scraping company reviews - KLA
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (164/170) Scraping company reviews - Dropbox
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (165/170) Scraping company reviews - Thales Defense & Security, Inc.
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (166/170) Scraping company reviews - Comcast
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (167/170) Scraping company reviews - Clio Area Schools
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (168/170) Scraping company reviews - FreeWheel
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (169/170) Scraping company reviews - General Dynamics Land Systems
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100
#
# (170/170) Scraping company reviews - Flexport
# Progress -  20 / 100
# Progress -  40 / 100
# Progress -  60 / 100
# Progress -  80 / 100
# Progress -  100 / 100

# %%
driver.quit()

import pandas as pd
df = pd.DataFrame()
for company in reviews:
    tempm = {}
    tempm['Company'] = company
    tempm['Reviews'] = reviews[company]
    df = df.append(tempm, ignore_index=True)

df.to_csv('out.csv',sep='|', index=False)

# %%
# print("Writing data to CSV")
# with open('../dataset/dataset.csv', 'w') as f:
#     writer = csv.writer(f)
#     for company in reviews:
#         rowData = [company, reviews[company]]
#         writer.writerow(rowData)
# Out:
# Writing data to CSV
